# %%
drug = {
    "drug": "paracetamol",
    "common_strength": "500mg",
    "email": "analgesic"
}

# %%
drug_list = {
    "drug": ["paracetamol"],
    "common_strength": ["500mg"],
    "drug_class": ["analgesic"]
}

# %%
drug_list = {
    "drug_name": ["paracetamol", 'amoxicillin', 'cefixime'],
    "common_strenght": ["500mg", '625mg', '200mg'],
    "drug_class": ["analgesic", 'bacterial infections', 'antibiotic']
}

# %%
drug_list['drug_name']
# Out:
# ['paracetamol', 'amoxicillin', 'cefixime']

# %%
import pandas as pd

# %%
df = pd.DataFrame(drug_list)

# %%
df
# Out:
#      drug_name common_strenght            drug_class
# 0  paracetamol           500mg             analgesic
# 1  amoxicillin           625mg  bacterial infections
# 2     cefixime           200mg            antibiotic

# %%
df['drug_class']
# Out:
# 0               analgesic
# 1    bacterial infections
# 2              antibiotic
# Name: drug_class, dtype: object

# %%
df.drug_class
# Out:
# 0               analgesic
# 1    bacterial infections
# 2              antibiotic
# Name: drug_class, dtype: object

# %%
df[['drug_name', 'drug_class']]
# Out:
#      drug_name            drug_class
# 0  paracetamol             analgesic
# 1  amoxicillin  bacterial infections
# 2     cefixime            antibiotic

# %%
df.columns
# Out:
# Index(['drug_name', 'common_strenght', 'drug_class'], dtype='object')

# %%
df.iloc[[1,2], 2]
# Out:
# 1    bacterial infections
# 2              antibiotic
# Name: drug_class, dtype: object

# %%
df
# Out:
#      drug_name common_strenght            drug_class
# 0  paracetamol           500mg             analgesic
# 1  amoxicillin           625mg  bacterial infections
# 2     cefixime           200mg            antibiotic

# %%
df.loc[[0,1],['drug_class', 'common_strenght']]
# Out:
#              drug_class common_strenght
# 0             analgesic           500mg
# 1  bacterial infections           625mg
