# %%
drug_list = {
    "drug_name": ["paracetamol", 'amoxicillin', 'cefixime'],
    "common_strenght": ["500mg", '625mg', '200mg'],
    "drug_class": ["analgesic", 'bacterial infections', 'antibiotic']
}

# %%
import pandas as pd

# %%
df = pd.DataFrame(drug_list)

# %%
df
# Out:
#      drug_name common_strenght            drug_class
# 0  paracetamol           500mg             analgesic
# 1  amoxicillin           625mg  bacterial infections
# 2     cefixime           200mg            antibiotic

# %%
#df.set_index('drug_class', inplace=True)

# %%
#filt = (df['common_strenght'] == '500mg') | (df['drug_name'] == 'cefixime')

# %%
#df.loc[filt, 'drug_class']

# %%
#df.rename(columns={'drug_name':'drug', 'common_strength':'mg'})

# %%
#df.loc[2] = ['cefixine', '250mg', 'antibiotic']

# %%
#df.loc[2, ['common_strength', 'drug_class']] = ['200mg', 'ANTIBIOTIC']

# %%
#df.loc[2, 'common_strength'] = '350mg'

# %%
df['drug_class'].apply(len)
# Out:
# 0     9
# 1    20
# 2    10
# Name: drug_class, dtype: int64

# %%
def update_drug_class(drug_class):
    return drug_class.upper()

# %%
df['drug_class'].apply(update_drug_class)
# Out:
# 0               ANALGESIC
# 1    BACTERIAL INFECTIONS
# 2              ANTIBIOTIC
# Name: drug_class, dtype: object

# %%
df['drug_class'] = df['drug_class'].apply(update_drug_class)

# %%
df['drug_class'] = df['drug_class'].apply(lambda x: x.lower())

# %%
df
# Out:
#      drug_name common_strenght            drug_class
# 0  paracetamol           500mg             analgesic
# 1  amoxicillin           625mg  bacterial infections
# 2     cefixime           200mg            antibiotic

# %%
df['drug_class'].apply(len)
# Out:
# 0     9
# 1    20
# 2    10
# Name: drug_class, dtype: int64

# %%
df.apply(len, axis='columns')
# Out:
# 0    3
# 1    3
# 2    3
# dtype: int64

# %%
len(df['drug_class'])
# Out:
# 3

# %%
df.apply(lambda x: x.min())
# Out:
# drug_name          amoxicillin
# common_strenght          200mg
# drug_class           analgesic
# dtype: object

# %%
df.applymap(len)
# Out:
# C:\Users\khara\AppData\Local\Temp\ipykernel_21088\1485728669.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df.applymap(len)
#    drug_name  common_strenght  drug_class
# 0         11                5           9
# 1         11                5          20
# 2          8                5          10

# %%
df.applymap(str.lower)
# Out:
# C:\Users\khara\AppData\Local\Temp\ipykernel_21088\357608748.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df.applymap(str.lower)
#      drug_name common_strenght            drug_class
# 0  paracetamol           500mg             analgesic
# 1  amoxicillin           625mg  bacterial infections
# 2     cefixime           200mg            antibiotic

# %%
df['drug_name'].map({'paracetamol': 'dolo','amoxicillin': 'cinarious'})
# Out:
# 0         dolo
# 1    cinarious
# 2          NaN
# Name: drug_name, dtype: object

# %%
df['drug_name'] = df['drug_name'].replace({'paracetamol': 'dolo','amoxicillin': 'cinarious'})

# %%
df
# Out:
#    drug_name common_strenght            drug_class
# 0       dolo           500mg             analgesic
# 1  cinarious           625mg  bacterial infections
# 2   cefixime           200mg            antibiotic
