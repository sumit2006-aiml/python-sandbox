# %%
import pandas as pd

# %%
df = pd.read_csv('drugs.csv')

# %%
schema_df = pd.read_csv('drugs.csv')

# %%
pd.set_option('display.max_columns', 8)
pd.set_option('display.max_rows', 8)

# %%
df.head()
# Out:
#             Drug     mg                              Use Chemical Formula  \
# 0  Acetaminophen  500.0      Pain relief / fever reducer          C8H9NO2
# 1      Ibuprofen  400.0  Pain relief / anti-inflammatory         C13H18O2
# 2        Aspirin  325.0      Pain relief / blood thinner           C9H8O4
# 3   Atorvastatin   20.0           Cholesterol management      C33H35FN2O5
# 4      Metformin  500.0       Type 2 diabetes management          C4H11N5
#
#   Drug Class             Solubility  Melting Point (°C) Half-Life (hours)
# 0  Analgesic       Slightly soluble               169.0               2-3
# 1      NSAID         Poorly soluble                76.0                 2
# 2      NSAID       Slightly soluble               136.0               3-6
# 3     Statin  Practically insoluble               159.0                14
# 4  Biguanide         Freely soluble               224.0                 6

# %%
schema_df
# Out:
#                    Drug      mg                                  Use  \
# 0         Acetaminophen   500.0          Pain relief / fever reducer
# 1             Ibuprofen   400.0      Pain relief / anti-inflammatory
# 2               Aspirin   325.0          Pain relief / blood thinner
# 3          Atorvastatin    20.0               Cholesterol management
# 4             Metformin   500.0           Type 2 diabetes management
# 5           Amoxicillin   500.0                 Bacterial infections
# 6            Sertraline    50.0                 Depression / anxiety
# 7            Fluoxetine    20.0                     Depression / OCD
# 8            Furosemide    40.0       Fluid retention / hypertension
# 9           Clopidogrel    75.0                Blood clot prevention
# 10           Omeprazole    20.0                   Acid reflux / GERD
# 11             Losartan    50.0                         Hypertension
# 12           Lisinopril    10.0         Hypertension / heart failure
# ...

# %%
df.shape
# Out:
# (60, 8)

# %%
df.columns
# Out:
# Index(['Drug', 'mg', 'Use', 'Chemical Formula', 'Drug Class', 'Solubility',
#        'Melting Point (°C)', 'Half-Life (hours)'],
#       dtype='object')

# %%
df['Use']
# Out:
# Use
# Bacterial infections               10
# Blood clot prevention               4
# Pain relief                         4
# Depression / anxiety                3
#                                    ..
# Hypertension / heart disease        1
# Diabetes (long-acting insulin)      1
# Diabetes (rapid-acting insulin)     1
# Autoimmune disorders / cancer       1
# Name: count, Length: 35, dtype: int64

# %%
df.loc[0:4, 'Drug Class':'Solubility']
# Out:
#   Drug Class             Solubility
# 0  Analgesic       Slightly soluble
# 1      NSAID         Poorly soluble
# 2      NSAID       Slightly soluble
# 3     Statin  Practically insoluble
# 4  Biguanide         Freely soluble
